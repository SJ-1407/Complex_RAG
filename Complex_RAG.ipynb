# %%
! pip install -U langchain-nomic langchain_community tiktoken langchainhub chromadb langchain langgraph tavily-python gpt4all
# Out:
# Requirement already satisfied: langchain-nomic in c:\users\shrey\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: langchain_community in c:\users\shrey\anaconda3\lib\site-packages (0.0.38)
# Requirement already satisfied: tiktoken in c:\users\shrey\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: langchainhub in c:\users\shrey\anaconda3\lib\site-packages (0.1.15)
# Requirement already satisfied: chromadb in c:\users\shrey\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: langchain in c:\users\shrey\anaconda3\lib\site-packages (0.1.20)
# Requirement already satisfied: langgraph in c:\users\shrey\anaconda3\lib\site-packages (0.0.49)
# Requirement already satisfied: tavily-python in c:\users\shrey\anaconda3\lib\site-packages (0.3.3)
# Requirement already satisfied: gpt4all in c:\users\shrey\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: langchain-core<0.3,>=0.1.46 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-nomic) (0.1.52)
# Requirement already satisfied: nomic<4.0.0,>=3.0.12 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-nomic) (3.0.28)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\shrey\anaconda3\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\shrey\anaconda3\lib\site-packages (from langchain_community) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from langchain_community) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from langchain_community) (0.6.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from langchain_community) (0.1.57)
# Requirement already satisfied: numpy<2,>=1 in c:\users\shrey\anaconda3\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\shrey\anaconda3\lib\site-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\shrey\anaconda3\lib\site-packages (from langchainhub) (2.31.0.20240406)
# Requirement already satisfied: build>=1.0.3 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.10.12)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.29.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (4.9.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.17.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.63.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (3.10.3)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from langchain) (0.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\shrey\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\shrey\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\shrey\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\shrey\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.3)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\shrey\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.26.0)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\shrey\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.3)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\shrey\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (5.4.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.1.1)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from langchain-core<0.3,>=0.1.46->langchain-nomic) (1.33)
# Requirement already satisfied: click in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (8.1.7)
# Requirement already satisfied: jsonlines in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (4.0.0)
# Requirement already satisfied: loguru in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (0.7.2)
# Requirement already satisfied: rich in c:\users\shrey\appdata\roaming\python\python311\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (13.7.1)
# Requirement already satisfied: pandas in c:\users\shrey\appdata\roaming\python\python311\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (2.2.1)
# Requirement already satisfied: pyarrow in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (14.0.2)
# Requirement already satisfied: pillow in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (10.2.0)
# Requirement already satisfied: pyjwt in c:\users\shrey\appdata\roaming\python\python311\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (2.8.0)
# Requirement already satisfied: coloredlogs in c:\users\shrey\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\shrey\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\shrey\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in c:\users\shrey\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.2.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\shrey\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\shrey\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrey\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrey\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\shrey\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\shrey\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.23.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\shrey\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: h11>=0.8 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shrey\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\shrey\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: anyio in c:\users\shrey\anaconda3\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\shrey\anaconda3\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\shrey\anaconda3\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: filelock in c:\users\shrey\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\shrey\anaconda3\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrey\anaconda3\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.46->langchain-nomic) (2.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shrey\anaconda3\lib\site-packages (from rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (2.15.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\shrey\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from loguru->nomic<4.0.0,>=3.0.12->langchain-nomic) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrey\anaconda3\lib\site-packages (from pandas->nomic<4.0.0,>=3.0.12->langchain-nomic) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shrey\anaconda3\lib\site-packages (from pandas->nomic<4.0.0,>=3.0.12->langchain-nomic) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\shrey\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\shrey\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shrey\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\shrey\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %%
# !pip install langchain-nomic
# Out:
# Requirement already satisfied: langchain-nomic in c:\users\shrey\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: langchain-core<0.3,>=0.1.46 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-nomic) (0.1.52)
# Requirement already satisfied: nomic<4.0.0,>=3.0.12 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-nomic) (3.0.28)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain-nomic) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from langchain-core<0.3,>=0.1.46->langchain-nomic) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain-nomic) (0.1.57)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain-nomic) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain-nomic) (1.10.12)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain-nomic) (8.3.0)
# Requirement already satisfied: click in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (8.1.7)
# Requirement already satisfied: jsonlines in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (4.0.0)
# Requirement already satisfied: loguru in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (0.7.2)
# Requirement already satisfied: rich in c:\users\shrey\appdata\roaming\python\python311\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (13.7.1)
# Requirement already satisfied: requests in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (2.31.0)
# Requirement already satisfied: numpy in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (1.26.4)
# Requirement already satisfied: pandas in c:\users\shrey\appdata\roaming\python\python311\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (2.2.1)
# Requirement already satisfied: tqdm in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (4.65.0)
# Requirement already satisfied: pyarrow in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (14.0.2)
# Requirement already satisfied: pillow in c:\users\shrey\anaconda3\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (10.2.0)
# Requirement already satisfied: pyjwt in c:\users\shrey\appdata\roaming\python\python311\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (2.8.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.46->langchain-nomic) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\shrey\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.3,>=0.1.46->langchain-nomic) (3.10.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.46->langchain-nomic) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrey\anaconda3\lib\site-packages (from requests->nomic<4.0.0,>=3.0.12->langchain-nomic) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrey\anaconda3\lib\site-packages (from requests->nomic<4.0.0,>=3.0.12->langchain-nomic) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shrey\anaconda3\lib\site-packages (from requests->nomic<4.0.0,>=3.0.12->langchain-nomic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrey\anaconda3\lib\site-packages (from requests->nomic<4.0.0,>=3.0.12->langchain-nomic) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\lib\site-packages (from click->nomic<4.0.0,>=3.0.12->langchain-nomic) (0.4.6)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\shrey\appdata\roaming\python\python311\site-packages (from jsonlines->nomic<4.0.0,>=3.0.12->langchain-nomic) (23.2.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from loguru->nomic<4.0.0,>=3.0.12->langchain-nomic) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shrey\anaconda3\lib\site-packages (from pandas->nomic<4.0.0,>=3.0.12->langchain-nomic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrey\anaconda3\lib\site-packages (from pandas->nomic<4.0.0,>=3.0.12->langchain-nomic) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shrey\anaconda3\lib\site-packages (from pandas->nomic<4.0.0,>=3.0.12->langchain-nomic) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shrey\anaconda3\lib\site-packages (from rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shrey\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\shrey\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->nomic<4.0.0,>=3.0.12->langchain-nomic) (1.16.0)

# %%
local_llm = "phi3"

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import GPT4AllEmbeddings

urls = [
    "https://lilianweng.github.io/posts/2023-06-23-agent/",
    "https://lilianweng.github.io/posts/2023-03-15-prompt-engineering/",
    "https://lilianweng.github.io/posts/2023-10-25-adv-attack-llm/",
]

docs = [WebBaseLoader(url).load() for url in urls]
docs_list = [item for sublist in docs for item in sublist]

text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=250, chunk_overlap=0
)
doc_splits = text_splitter.split_documents(docs_list)

# Add to vectorDB
vectorstore = Chroma.from_documents(
    documents=doc_splits,
    collection_name="rag-chroma",
    embedding=GPT4AllEmbeddings(),
)
retriever = vectorstore.as_retriever()

# %%
### Retrieval Grader

from langchain.prompts import PromptTemplate
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import JsonOutputParser

# LLM
llm = ChatOllama(model=local_llm, format="json", temperature=0)

prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> You are a grader assessing relevance 
    of a retrieved document to a user question. If the document contains keywords related to the user question, 
    grade it as relevant. It does not need to be a stringent test. The goal is to filter out erroneous retrievals. \n
    Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question. \n
    Provide the binary score as a JSON with a single key 'score' and no premable or explanation.
     <|eot_id|><|start_header_id|>user<|end_header_id|>
    Here is the retrieved document: \n\n {document} \n\n
    Here is the user question: {question} \n <|eot_id|><|start_header_id|>assistant<|end_header_id|>
    """,
    input_variables=["question", "document"],
)

retrieval_grader = prompt | llm | JsonOutputParser()
question = "agent memory"
docs = retriever.invoke(question)
doc_txt = docs[1].page_content
print(retrieval_grader.invoke({"question": question, "document": doc_txt}))
# Out:
# {'score': 'yes'}

# %%
### Generate

from langchain.prompts import PromptTemplate
from langchain import hub
from langchain_core.output_parsers import StrOutputParser

# Prompt
prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> You are an assistant for question-answering tasks. 
    Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. 
    Use three sentences maximum and keep the answer concise <|eot_id|><|start_header_id|>user<|end_header_id|>
    Question: {question} 
    Context: {context} 
    Answer: <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
    input_variables=["question", "document"],
)

llm = ChatOllama(model=local_llm, temperature=0)


# Post-processing
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


# Chain
rag_chain = prompt | llm | StrOutputParser()

# Run
question = "agent memory"
docs = retriever.invoke(question)
generation = rag_chain.invoke({"context": docs, "question": question})
print(generation)
# Out:
# The agent memory is a long-term memory module, also known as an external database, that records a comprehensive list of agents' experiences in natural language. This allows the agent to behave conditioned on past experience and interact with other agents.

# %%
### Hallucination Grader

# LLM
llm = ChatOllama(model=local_llm, format="json", temperature=0)

# Prompt
prompt = PromptTemplate(
    template=""" <|begin_of_text|><|start_header_id|>system<|end_header_id|> You are a grader assessing whether 
    an answer is grounded in / supported by a set of facts. Give a binary 'yes' or 'no' score to indicate 
    whether the answer is grounded in / supported by a set of facts. Provide the binary score as a JSON with a 
    single key 'score' and no preamble or explanation. <|eot_id|><|start_header_id|>user<|end_header_id|>
    Here are the facts:
    \n ------- \n
    {documents} 
    \n ------- \n
    Here is the answer: {generation}  <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
    input_variables=["generation", "documents"],
)

hallucination_grader = prompt | llm | JsonOutputParser()
hallucination_grader.invoke({"documents": docs, "generation": generation})

# %%
### Answer Grader

# LLM
llm = ChatOllama(model=local_llm, format="json", temperature=0)

# Prompt
prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> You are a grader assessing whether an 
    answer is useful to resolve a question. Give a binary score 'yes' or 'no' to indicate whether the answer is 
    useful to resolve a question. Provide the binary score as a JSON with a single key 'score' and no preamble or explanation.
     <|eot_id|><|start_header_id|>user<|end_header_id|> Here is the answer:
    \n ------- \n
    {generation} 
    \n ------- \n
    Here is the question: {question} <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
    input_variables=["generation", "question"],
)

answer_grader = prompt | llm | JsonOutputParser()
answer_grader.invoke({"question": question, "generation": generation})

# %%
### Router

from langchain.prompts import PromptTemplate
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import JsonOutputParser

# LLM
llm = ChatOllama(model=local_llm, format="json", temperature=0)

prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> You are an expert at routing a 
    user question to a vectorstore or web search. Use the vectorstore for questions on LLM  agents, 
    prompt engineering, and adversarial attacks. You do not need to be stringent with the keywords 
    in the question related to these topics. Otherwise, use web-search. Give a binary choice 'web_search' 
    or 'vectorstore' based on the question. Return the a JSON with a single key 'datasource' and 
    no premable or explanation. Question to route: {question} <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
    input_variables=["question"],
)

'''question_router = prompt | llm | JsonOutputParser()
question = "llm agent memory"
docs = retriever.get_relevant_documents(question)
doc_txt = docs[1].page_content
print(question_router.invoke({"question": question}))'''
question_router = prompt | llm | JsonOutputParser()
question = "llm agent memory"

# Update this line to use invoke instead of get_relevant_documents
docs = retriever.invoke(question)  # Assuming the retriever supports invoke

doc_txt = docs[1].page_content
print(question_router.invoke({"question": question}))

# %%
### Search
import os
import getpass

# Prompt for API key securely
api_key = getpass.getpass("Enter your Tavily API key: ")

# Optionally, set it as an environment variable for use in other parts of the code
os.environ["TAVILY_API_KEY"] = api_key

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

web_search_tool = TavilySearchResults(k=3)

# %%
from typing_extensions import TypedDict
from typing import List

### State


class GraphState(TypedDict):
    """
    Represents the state of our graph.

    Attributes:
        question: question
        generation: LLM generation
        web_search: whether to add search
        documents: list of documents
    """

    question: str
    generation: str
    web_search: str
    documents: List[str]


from langchain.schema import Document

### Nodes


def retrieve(state):
    """
    Retrieve documents from vectorstore

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, documents, that contains retrieved documents
    """
    print("---RETRIEVE---")
    question = state["question"]

    # Retrieval
    documents = retriever.invoke(question)
    return {"documents": documents, "question": question}


def generate(state):
    """
    Generate answer using RAG on retrieved documents

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, generation, that contains LLM generation
    """
    print("---GENERATE---")
    question = state["question"]
    documents = state["documents"]

    # RAG generation
    generation = rag_chain.invoke({"context": documents, "question": question})
    return {"documents": documents, "question": question, "generation": generation}


def grade_documents(state):
    """
    Determines whether the retrieved documents are relevant to the question
    If any document is not relevant, we will set a flag to run web search

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Filtered out irrelevant documents and updated web_search state
    """

    print("---CHECK DOCUMENT RELEVANCE TO QUESTION---")
    question = state["question"]
    documents = state["documents"]

    # Score each doc
    filtered_docs = []
    web_search = "No"
    for d in documents:
        score = retrieval_grader.invoke(
            {"question": question, "document": d.page_content}
        )
        grade = score["score"]
        # Document relevant
        if grade.lower() == "yes":
            print("---GRADE: DOCUMENT RELEVANT---")
            filtered_docs.append(d)
        # Document not relevant
        else:
            print("---GRADE: DOCUMENT NOT RELEVANT---")
            # We do not include the document in filtered_docs
            # We set a flag to indicate that we want to run web search
            web_search = "Yes"
            continue
    return {"documents": filtered_docs, "question": question, "web_search": web_search}


def web_search(state):
    """
    Web search based based on the question

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Appended web results to documents
    """

    print("---WEB SEARCH---")
    question = state["question"]
    documents = state["documents"]

    # Web search
    docs = web_search_tool.invoke({"query": question})
    web_results = "\n".join([d["content"] for d in docs])
    web_results = Document(page_content=web_results)
    if documents is not None:
        documents.append(web_results)
    else:
        documents = [web_results]
    return {"documents": documents, "question": question}


### Conditional edge


def route_question(state):
    """
    Route question to web search or RAG.

    Args:
        state (dict): The current graph state

    Returns:
        str: Next node to call
    """

    print("---ROUTE QUESTION---")
    question = state["question"]
    print(question)
    source = question_router.invoke({"question": question})
    print(source)
    print(source["datasource"])
    if source["datasource"] == "web_search":
        print("---ROUTE QUESTION TO WEB SEARCH---")
        return "websearch"
    elif source["datasource"] == "vectorstore":
        print("---ROUTE QUESTION TO RAG---")
        return "vectorstore"


def decide_to_generate(state):
    """
    Determines whether to generate an answer, or add web search

    Args:
        state (dict): The current graph state

    Returns:
        str: Binary decision for next node to call
    """

    print("---ASSESS GRADED DOCUMENTS---")
    question = state["question"]
    web_search = state["web_search"]
    filtered_documents = state["documents"]

    if web_search == "Yes":
        # All documents have been filtered check_relevance
        # We will re-generate a new query
        print(
            "---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, INCLUDE WEB SEARCH---"
        )
        return "websearch"
    else:
        # We have relevant documents, so generate answer
        print("---DECISION: GENERATE---")
        return "generate"


### Conditional edge


def grade_generation_v_documents_and_question(state):
    """
    Determines whether the generation is grounded in the document and answers question.

    Args:
        state (dict): The current graph state

    Returns:
        str: Decision for next node to call
    """

    print("---CHECK HALLUCINATIONS---")
    question = state["question"]
    documents = state["documents"]
    generation = state["generation"]

    score = hallucination_grader.invoke(
        {"documents": documents, "generation": generation}
    )
    grade = score["score"]

    # Check hallucination
    if grade == "yes":
        print("---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---")
        # Check question-answering
        print("---GRADE GENERATION vs QUESTION---")
        score = answer_grader.invoke({"question": question, "generation": generation})
        grade = score["score"]
        if grade == "yes":
            print("---DECISION: GENERATION ADDRESSES QUESTION---")
            return "useful"
        else:
            print("---DECISION: GENERATION DOES NOT ADDRESS QUESTION---")
            return "not useful"
    else:
        pprint("---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---")
        return "not supported"


from langgraph.graph import END, StateGraph

workflow = StateGraph(GraphState)

# Define the nodes
workflow.add_node("websearch", web_search)  # web search
workflow.add_node("retrieve", retrieve)  # retrieve
workflow.add_node("grade_documents", grade_documents)  # grade documents
workflow.add_node("generate", generate)  # generatae

# %%
# Build graph
workflow.set_conditional_entry_point(
    route_question,
    {
        "websearch": "websearch",
        "vectorstore": "retrieve",
    },
)

workflow.add_edge("retrieve", "grade_documents")
workflow.add_conditional_edges(
    "grade_documents",
    decide_to_generate,
    {
        "websearch": "websearch",
        "generate": "generate",
    },
)
workflow.add_edge("websearch", "generate")
workflow.add_conditional_edges(
    "generate",
    grade_generation_v_documents_and_question,
    {
        "not supported": "generate",
        "useful": END,
        "not useful": "websearch",
    },
)

# %%
# Compile
app = workflow.compile()

# Test
from pprint import pprint

inputs = {"question": "What are the types of agent memory?"}
for output in app.stream(inputs):
    for key, value in output.items():
        pprint(f"Finished running: {key}:")
pprint(value["generation"])

# %%
# Compile
app = workflow.compile()

# Test
from pprint import pprint

inputs = {"question": "What is the age of earth"}
for output in app.stream(inputs):
    for key, value in output.items():
        pprint(f"Finished running: {key}:")
pprint(value["generation"])
